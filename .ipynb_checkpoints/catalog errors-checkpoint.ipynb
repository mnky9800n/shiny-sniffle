# %%
# %matplotlib inline
import pandas as pd
from mpl_toolkits.basemap import Basemap
import numpy as np
from utilities import timestamps
from utilities.plotting import equi
from utilities.polygon_selection import get_node_data
from utilities.stats import calc_fmd_stats_with_mc
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/ccu.dat', delimiter='\t', names=['lon', 'lat', 'decimal_year', 'month', 'day', 'mag'
                                                        , 'depth', 'hour', 'minute', 'second', 'horizontal_error'
                                                        , 'depth_error', 'mag_err'])

# %%
df.head()
# Out:
#           lon        lat  decimal_year  month   day  mag  depth  hour  minute  \
# 0  139.963333  37.326667   1989.998997   12.0  31.0  1.9    6.4  15.0    12.0
# 1  137.620000  34.813333   1989.999023   12.0  31.0  1.4   28.0  15.0    26.0
# 2  142.820000  41.473333   1989.999336   12.0  31.0  2.7   35.0  18.0    11.0
# 3  137.648333  35.233333   1989.999479   12.0  31.0  1.3   14.3  19.0    25.0
# 4  140.273333  34.355000   1989.999492   12.0  31.0  2.3   51.0  19.0    32.0
#
#       second  horizontal_error  depth_error  mag_err
# 0  50.900002          1.752955          3.7      NaN
# 1  39.499997          1.062217          1.3      NaN
# 2   2.200001          6.021544          NaN      NaN
# 3  57.299998          0.822034          1.5      NaN
# 4  44.399997          3.503555          NaN      NaN

# %%
df['timestamp'] = df.decimal_year.apply(timestamps.convert_decimal_year_to_numpy_datetime64)

# %%
df = df.set_index('timestamp')

# %%
df.mag.plot(figsize=(15,5))

# %%
df.horizontal_error.describe()
# Out:
# count    2.697507e+06
# mean     1.358280e+00
# std      1.777178e+00
# min      0.000000e+00
# 25%      3.718988e-01
# 50%      7.852691e-01
# 75%      1.696870e+00
# max      1.739248e+02
# Name: horizontal_error, dtype: float64

# %%
df.horizontal_error.hist(bins=100, range=(0,2))

# %%
fig, ax = plt.subplots(1, figsize=(8,8))

m = Basemap(projection='merc'
           ,llcrnrlat=28.5
           ,urcrnrlat=34.5
           ,llcrnrlon=126.5
           ,urcrnrlon=134.5
           ,resolution='i'
           ,area_thresh=1000
           ,ax=ax)

labels = np.arange(0,180,2)
m.drawparallels(labels, labels=labels)
m.drawmeridians(labels, labels=labels)

m.drawcoastlines()
m.fillcontinents(color='gray', zorder=0)

# # data = df[(df.mag > 2.5) & df.lat.between(32,34) & df.lon.between(130,132)]
d = df[(df.mag > 3)].copy()
d = d[d.lat.between(28.5, 34.5) & d.lon.between(126.5, 134.5)]
d = d[d.horizontal_error <= 2.0]


x, y = m(d.lon.values, d.lat.values)

cbar = ax.scatter(x, y, c=d.horizontal_error.values, s=10*np.exp(d.horizontal_error.values), edgecolor='None'
                  , cmap='Reds')
c1 = fig.colorbar(cbar, label='horizontal error',fraction=0.0346, pad=0.084)
c1.ax.invert_yaxis()

# sizes = np.exp([3,4,5,6,7])
# label_plot = [ax.scatter([],[], s=s, edgecolors='black', color='white', alpha=0.5) for s in sizes]
# labels = [x for x in range(3,11)]
# ax.legend(label_plot, labels, ncol=10, frameon=True, fontsize=12, handlelength=0.75, loc='upper left'
#         , borderpad = 1.,handletextpad=0.95, title='Magnitude Size', scatterpoints = 1
#         , bbox_to_anchor=(0.18,0.0115))

# equi(m, 130, 30, 50, lw=2)
# equi(m, 132, 32, 50, lw=2)
# equi(m, 130, 34, 50, lw=2, color='red')

# %%
def get_cumdist(data):
    hist, edges = np.histogram(a=data, bins=100, range=(0,10))
    chist = np.cumsum(hist[::-1])
    return edges, hist, chist

def plot_data_with_fit_line(ax, raw_data, chist, radius, **kwargs):
    a, b, bstd, n, mc = calc_fmd_stats_with_mc(raw_data.mag)
    label = radius + ', b={b}, mc={mc}, n={n}'.format(b=round(b,4),mc=mc,n=n)
    ax.scatter(chist[0][::-1][:-1], chist[2], label=label, **kwargs)
#     a, b, bstd, n, mc = calc_fmd_stats_with_mc(raw_data.mag)
    x = np.arange(0, 10, 0.1)
    y = 10**(a - b * x)
    ax.plot(x, y, color='black')

# %% [markdown]
# # 4 locations from before (low/high b, max slip, hypocenter)

# %%
max_slip = (130.9372, 32.84189)
fm_main = (130.763, 32.7545)#, 128, 74, -14)
high_b = (131.25, 33.15,)
low_b = (130.5, 32.5)

# %%
df_min = df[df.mag > 1.5].copy()

# %%
get_node_data(node=low_b, radius=15, data=df_min).describe()
# Out:
#               lon         lat  decimal_year       month         day  \
# count  707.000000  707.000000    707.000000  707.000000  707.000000
# mean   130.594201   32.508022   2008.688548    5.783593   16.135785
# std      0.057949    0.053837      8.439161    2.949502    8.059004
# min    130.411500   32.362333   1990.092480    1.000000    1.000000
# 25%    130.552334   32.475833   2001.285879    4.000000    9.500000
# 50%    130.596667   32.512667   2012.182063    5.000000   17.000000
# 75%    130.647917   32.545250   2016.308681    8.000000   22.000000
# max    130.678833   32.636167   2016.457452   12.000000   31.000000
#
#               mag       depth        hour      minute      second  \
# count  707.000000  707.000000  707.000000  707.000000  707.000000
# mean     2.258699    8.922603   12.031117   29.649222   28.482447
# std      0.614663    2.570854    6.826597   17.050459   17.106421
# min      1.600000    0.000000    0.000000    0.000000    0.039999
# 25%      1.800000    7.360000    7.000000   15.500000   14.179998
# 50%      2.100000    9.050000   12.000000   29.000000   28.199997
# 75%      2.600000   10.580000   18.000000   44.000000   42.535000
# max      5.500000   15.700000   23.000000   59.000000   59.990002
#
#        horizontal_error  depth_error  mag_err    distance
# count        707.000000   687.000000      0.0  707.000000
# mean           0.510945     1.286492      NaN   10.027804
# std            0.407979     0.598246      NaN    3.431629
# min            0.169813     0.450000      NaN    2.205089
# 25%            0.325497     0.915000      NaN    7.421215
# 50%            0.406615     1.100000      NaN   10.528071
# 75%            0.466228     1.505000      NaN   12.894551
# max            3.919407     4.600000      NaN   14.987739

# %%
df['hz_err_deg'] = df['horizontal_error'] / 111.113

# %%
np.random.random()
# Out:
# 0.09171929198124096

# %%
loc_err_df = df.copy()
loc_err_df['lon'] = loc_err_df['lon'] + np.random.random() * loc_err_df['horizontal_error']
loc_err_df['lat'] = loc_err_df['lat'] + np.random.random() * loc_err_df['horizontal_error']
node_df = get_node_data(node=fm_main, radius=15, data=loc_err_df)
a, b, bstd, n, mc = calc_fmd_stats_with_mc(node_df.mag)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2597612e5ecf> in <module>()
#       3 loc_err_df['lat'] = loc_err_df['lat'] + np.random.random() * loc_err_df['horizontal_error']
#       4 node_df = get_node_data(node=fm_main, radius=15, data=loc_err_df)
# ----> 5 a, b, bstd, n, mc = calc_fmd_stats_with_mc(node_df.mag)
#
# NameError: name 'calc_fmd_stats_with_mc' is not defined
