# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from utilities import plotting
from utilities import stats
from utilities import timestamps
from utilities import import_export
from utilities import polygon_selection
from mpl_toolkits.basemap import Basemap
from itertools import product
import matplotlib.pyplot as plt
from obspy.imaging.beachball import beach
import bs4 as bs
import matplotlib as mpl
from matplotlib.patches import Polygon as pg

def calc_b_with_time_window(dataframe, n_eq, time_window_center):
    df_window = dataframe.copy()
    time_window_index = df_window.index.get_loc(time_window_center, method='pad')
    
    lower_index = time_window_index - n_eq
    if lower_index < 0:
        lower_index = 0
    
#     df_window = df_window.ix[time_window_index - n_eq : time_window_index + n_eq]
    df_window = df_window.ix[lower_index : time_window_index + n_eq]
    a, b, bstd, n, mc = stats.calc_fmd_stats_with_mc(df_window.mag)
    return a, b, bstd, n, mc, time_window_index

def calc_b_value_for_parameters(dataframe, parameters, location):
    # TODO: will multiprocessing speed this up?
    rows = []
    for r, t in parameters:
        try:
#             for r, t in parameters:
            df_c = polygon_selection.get_node_data(node=location, data=dataframe, radius=r, m=1)
            df_c = df_c.loc[df_c.index >= t]

            a, b, bstd, n, mc = stats.calc_fmd_stats_with_mc(df_c.mag)
            row = np.array((r,) + (t,) + (a, b, bstd, n, mc) + tuple(location))
            rows.append(row)
        except:
            row = np.array((r,) + (t,) +(np.nan, np.nan, np.nan, np.nan, np.nan) + tuple(location))

    return rows

def calc_b_for_parameters_attr_iter(attr):
    dataframe, parameters, location = attr
    return calc_b_value_for_parameters(dataframe, parameters, location)

def plot_beach_ball(earthquake, m, ax, xoffset=0, yoffset=0, **kwargs):
    lon, lat = earthquake['coordinates']
    x, y = m(lon, lat)
    b = beach(earthquake['focal_mech'], xy=(x + xoffset, y + yoffset), **kwargs)
    b.set_zorder(101)
    ax.add_collection(b)
    
def parse_coords(c):
    c = c.replace('\t', '')
    c = c.replace('\n', '')
    c = c.strip()
    c = c.split(' ')
    c = [[float(co) for co in coord.split(',')] for coord in c]
    c = np.array([np.array(co) for co in c])
    return c

# %%
kumamoto = {'coordinates':(130.763, 32.7545), 'time':'2016-04-14 12:26:00', 'tz':'UTC', 'magnitude':7.0, 'name':'Kumamoto', 'focal_mech':[128  , 71 , -14]}
foreshock1 = {'focal_mech':[299, 79, -10], 'magnitude':6.5, 'coordinates':[130.808667, 32.741667]}
foreshock2 = {'focal_mech':[30, 77, 180], 'magnitude':6.4, 'coordinates':(130.777667, 32.700667)}

# %%
df = import_export.import_catalog(location='data/ccu.dat', delimiter='\t', names=['lon', 'lat', 'decimal_year', 'month', 'day', 'mag'
                                                        , 'depth', 'hour', 'minute', 'second', 'horizontal_error'
                                                        , 'depth_error', 'mag_err'])
eq = kumamoto

df_regional = polygon_selection.get_node_data(data=df, node=eq['coordinates'], radius=2 * RL, m=1)
df_regional = df_regional.loc[df_regional.index < eq['time']]
# df_regional = df_regional.loc[df_regional.index > '01-01-2001']
df_regional = df_regional[df_regional.depth <=25]
df_regional = df_regional[df_regional.mag >= 0.5]

soup = bs.BeautifulSoup(open('/home/max/research/kumamoto/data/kyushu_fault.kml'), 'lxml')
fault_coordinates = [parse_coords(tag.text) for tag in soup.findAll('coordinates')]

# %%
df_regional.describe()
# Out:
#                 lon           lat  decimal_year         month           day  \
# count  65566.000000  65566.000000  65566.000000  65566.000000  65566.000000
# mean     130.731639     32.789794   2006.080083      6.537626     15.562258
# std        0.415020      0.356187      6.127631      3.410815      8.775564
# min      129.804667     31.946833   1990.007888      1.000000      1.000000
# 25%      130.495542     32.541833   2001.103904      4.000000      8.000000
# 50%      130.748333     32.821584   2006.427160      6.000000     15.000000
# 75%      130.969291     33.048000   2011.342156     10.000000     23.000000
# max      131.724000     33.555833   2016.285374     12.000000     31.000000
#
#                 mag         depth          hour        minute        second  \
# count  65566.000000  65566.000000  65566.000000  65566.000000  6.556600e+04
# mean       1.001062      9.947205     11.545252     29.565964  3.003609e+01
# ...

# %% [markdown]
# # regional seismicity

# %%
df_regional['cnt'] = 1
df_regional['cnt'] = np.cumsum(df_regional['cnt'])

# %%
fig, ax = plt.subplots(figsize=(15, 5))

df_regional[df_regional.mag >= 2].mag.plot(ax=ax, marker='o', markeredgecolor='black', color='None')


ax2 = ax.twinx()
df_regional.cnt.plot(ax=ax2, color='red', linewidth=4)

ax.set_ylabel('Magnitude')
ax2.set_ylabel('Cumulative count of events')
ax.set_xlabel('')

ax.text(s=r'1.5 $\times$ rupture length 2016 Kumamoto Earthquake', x=pd.to_datetime('06-01-2004'), y=5.2, fontsize=15)

# fig.tight_layout()

fig.savefig('/home/max/Dropbox/Saves/v0003/mag_over_t.pdf', bbox_inches='tight')

# %%
df_regional[df_regional.mag > 4.9]
# Out:
#                                 lon        lat  decimal_year  month   day  \
# timestamp
# 1994-02-12 17:06:56.299978  130.495  32.085000   1994.117022    2.0  12.0
# 2000-06-08 00:32:46.129979  130.762  32.692333   2000.434488    6.0   8.0
#
#                             mag  depth  hour  minute     second  \
# timestamp
# 1994-02-12 17:06:56.299978  5.7   5.20  17.0     6.0  56.299999
# 2000-06-08 00:32:46.129979  5.0  10.31   0.0    32.0  46.130001
#
#                             horizontal_error  depth_error  mag_err   distance  \
# timestamp
# 1994-02-12 17:06:56.299978          0.962019         2.40      NaN  78.606627
# 2000-06-08 00:32:46.129979          0.466253         0.84      NaN   6.912982
#
#                               cnt
# timestamp
# 1994-02-12 17:06:56.299978   1597
# 2000-06-08 00:32:46.129979  13520

# %%
eq = kumamoto

data = polygon_selection.get_node_data(node=eq['coordinates'], data=df, radius=500, m=1)
data = data.loc[data.index <= eq['time']]

fig, ax = plt.subplots(1, figsize=(15, 15))


lon, lat = eq['coordinates']


m = Basemap(llcrnrlon=lon-1.25
            ,llcrnrlat=lat-3
            ,urcrnrlon=lon+3
            ,urcrnrlat=lat+1.25
#             , epsg=4269
            , projection='merc'
            , ax=ax
            , resolution='f'
            , area_thresh=1)
m.drawcoastlines()
m.fillcontinents(color='0.95', zorder=0)


#### DATA USED FOR CALCULATIONS
data2 = polygon_selection.get_node_data(node=eq['coordinates'], data=df, radius=50, m=1)

lons = data2[data2.mag >= 2]['lon'].values
lats = data2[data2.mag >= 2]['lat'].values

x, y = m(lons, lats)

# ax.scatter(x, y, s=np.exp(data[data.mag>=2].mag.values), zorder=2, color='blue', rasterized=True, alpha=0.05)

#### DATA OUTSIDE OF SELECTION PERIMETER

lons = data[data.mag >= 2]['lon'].values
lats = data[data.mag >= 2]['lat'].values

x, y = m(lons, lats)

ax.scatter(x, y, s=np.exp(data[data.mag>=2].mag.values), zorder=1, edgecolors='black'
           ,color='None', alpha=0.13, rasterized=True)

plot_beach_ball(earthquake=eq, m=m, ax=ax, width=eq['magnitude']/50.)

# # PLOT FAULT LINES
# for fault in fault_coordinates:
#     x, y = m(fault[:,0], fault[:,1])
#     ax.plot(x, y, color='red', linewidth=2, zorder=3)
    
# rect [left, bottom, width, height] 
ax2 = fig.add_axes([0.273, 0.125, 0.69, 0.43])


lon, lat = eq['coordinates']

twice_RL = 90.

dist_in_deg = twice_RL/111.111

lats_box = [lat-dist_in_deg, lat+dist_in_deg, lat+dist_in_deg, lat-dist_in_deg]
lons_box = [lon-dist_in_deg, lon-dist_in_deg, lon+dist_in_deg, lon+dist_in_deg]


m2 = Basemap(projection='merc'
            ,llcrnrlon=lon-dist_in_deg
            ,llcrnrlat=lat-dist_in_deg
            ,urcrnrlon=lon+dist_in_deg
            ,urcrnrlat=lat+dist_in_deg
            , epsg=4269
            , ax=ax2
            , resolution='f'
            , area_thresh=1)

m2.drawcoastlines()
m2.fillcontinents(color='0.95', zorder=0)
lines = np.arange(0, 180, 0.5)
m2.drawparallels(lines, labels=[0,1,0,0], fontsize=15)
m2.drawmeridians(lines, labels=[0,0,0,1], fontsize=15)
# m.arcgisimage(service='World_Shaded_Relief', xpixels = 1500, verbose= True
#              ,zorder=0)

#### DATA USED FOR CALCULATIONS
data2 = polygon_selection.get_node_data(node=eq['coordinates'], data=df, radius=twice_RL, m=1)

lons = data2[data2.mag >= 2]['lon'].values
lats = data2[data2.mag >= 2]['lat'].values

x, y = m2(lons, lats)

ax2.scatter(x, y, s=np.exp(data[data.mag>=2].mag.values), zorder=2, edgecolors='black'
           ,color='None', alpha=0.5, rasterized=True)

# mainshock
xoffset, yoffset = (-0.2, 0.2)
plot_beach_ball(earthquake=eq, m=m2, ax=ax2, width=0.1, alpha=0.95, xoffset=xoffset, yoffset=yoffset)
x, y = m2(eq['coordinates'][0], eq['coordinates'][1])
ax2.plot([x, x + xoffset], [y, y + yoffset], color='blue', marker='', linestyle='-', linewidth=4, zorder=100)

# foreshock 1
xoffset, yoffset = (0.2, 0)
plot_beach_ball(earthquake=foreshock1, m=m2, ax=ax2, width=0.07, alpha=0.95
                , facecolor='green', xoffset=xoffset, yoffset=yoffset)
x, y = m2(foreshock1['coordinates'][0], foreshock1['coordinates'][1])
ax2.plot([x, x + xoffset], [y, y + yoffset], color='green', marker='', linestyle='-', linewidth=4, zorder=100)

# foreshock 2
xoffset, yoffset = (0.2, -0.1)
plot_beach_ball(earthquake=foreshock2, m=m2, ax=ax2, width=0.07, alpha=0.95
                , facecolor='green', xoffset=xoffset, yoffset=yoffset)
x, y = m2(foreshock2['coordinates'][0], foreshock2['coordinates'][1])
ax2.plot([x, x + xoffset], [y, y + yoffset], color='green', marker='', linestyle='-', linewidth=4, zorder=100)


# PLOT FAULT LINES
for fault in fault_coordinates:
    x, y = m2(fault[:,0], fault[:,1])
    ax.plot(x, y, color='red', linewidth=2)
    ax2.plot(x, y, color='red', linewidth=2)
    
x, y = m2(131.0841, 32.8869)
ax2.text(s='Mt. Aso', x=x-0.05, y=y, fontsize=14, zorder=5)

# x, y = m(131.0841, 32.8869)
ax2.scatter(x, y, marker='^', s=500, color='red')


lat_km = 111.111
lon_km = (111.111 * np.cos(np.deg2rad(eq['coordinates'][1])))

x, y = m2([130.1, 130.1 + 25./lon_km], [32.1, 32.1])

ax2.plot(x, y, linestyle='-', marker='|', markersize=15, color='black', linewidth=3
       ,markeredgewidth=3)
x, y = m2(130.05 + 11./lon_km, 32.15)
ax2.text(s='25km', x=x, y=y, fontsize=12, bbox={'facecolor':'white', 'alpha':1., 'pad':5})


x, y = m(lons_box, lats_box)
xy = [z for z in zip(x, y)]
poly = pg(xy, facecolor='None', edgecolor='black', linestyle='-', linewidth=2, zorder=50)
ax.add_patch(poly)

# plotting.draw_screen_poly(lats=lats_box, lons=lons_box, m=m, ax=ax)

# fig.savefig('paper_plots/regional_seismicity.pdf', bbox_inches='tight')
# m.drawlsmask(land_color=(0, 0, 0, 0), ocean_color='deeppink', lakes=True)
# m.drawlsmask(land_color=(0, 0, 0, 0), ocean_color='w', lsmask=None
#              , lsmask_lons=None, lsmask_lats=None, lakes=True, resolution='f', grid=1.25)

# plt.tight_layout()

fig.savefig('/home/max/Dropbox/Saves/v0003/regional_seismicity.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10, 10))

lon, lat = eq['coordinates']

twice_RL = 90.

dist_in_deg = twice_RL/111.111

m = Basemap(projection='merc'
            ,llcrnrlon=lon-dist_in_deg
            ,llcrnrlat=lat-dist_in_deg
            ,urcrnrlon=lon+dist_in_deg
            ,urcrnrlat=lat+dist_in_deg
            , ax=ax
            , resolution='i'
            , area_thresh=1)

m.drawcoastlines()
m.fillcontinents(color='0.95', zorder=0)

lines = np.arange(0, 180, 0.5)
m.drawparallels(lines, labels=[1, 0, 0, 0], fontsize=15)
m.drawmeridians(lines, labels=[0,0,1,0], fontsize=15)

data = df_regional[df_regional.mag >= 2]
x, y = m(data.lon.values, data.lat.values)
# ax.scatter(x=x, y=y, s=np.exp(data.mag), alpha=0.5, color='None', edgecolor='black')
ax.scatter(x=x, y=y, s=np.exp(data.mag), alpha=0.5, c=data.depth, cmap='nipy_spectral')

# PLOT FAULT LINES
for fault in fault_coordinates:
    x, y = m(fault[:,0], fault[:,1])
    ax.plot(x, y, color='red', linewidth=2)    

for r in [5, 15, 20, 25, 45, 90]:
    plotting.equi(ax=ax, m=m, radius=r, centerlon=eq['coordinates'][0], centerlat=eq['coordinates'][1]
                 ,color='black')
    x, y = m(eq['coordinates'][0], eq['coordinates'][1]+(r+1)/111.111)
    ax.text(s='{r}km'.format(r=r), x=x, y=y, fontsize=20)

    
x, y = m(131.2, 32.05)
ax.text(s='$\geq$M2', fontsize=30, x=x, y=y)

ax3 = fig.add_axes([0.925, 0.15, 0.7, 0.7])
data2 = polygon_selection.get_node_data(node=eq['coordinates'], data=df_regional, radius=twice_RL, m=1)


RL = 45
for r in [5, 15, 20, 25, 45, 90]:

    
    eqs = polygon_selection.get_node_data(node=eq['coordinates']
                                          ,data=df_regional.loc[df_regional.index >= '01-01-2001']
                                          , radius=r, m=1)
    h, e = np.histogram(a=eqs.mag, bins=100, range=(0, 10))
    chist = np.cumsum(h[::-1])[::-1]
    
    a, b, bstd, n, mc = stats.calc_fmd_stats_with_mc(eqs.mag)
    ax3.scatter(e[:-1], chist, marker='s', alpha=0.5, label=None)
    
    x = np.arange(0, 10, 0.1)
    y = 10**(a - b * x)
    
    
    ax3.plot(x, y, label='R={r}km, b={b}'.format(r=r, b=round(b, 2))+'$\pm$'+'{bstd}'.format(bstd=round(bstd,2)))
    
ax3.set_yscale('log')
ax3.set_ylim(1e0, 10**a)
ax3.set_xlim(0, 6)
ax3.set_xlabel('Magnitude', fontsize=15)
ax3.set_ylabel('N Events', fontsize=15)
ax3.legend(fontsize=15)

for label in (ax3.get_xticklabels() + ax3.get_yticklabels()):
    label.set_fontsize(15)
# fig.savefig('/home/max/Dropbox/Saves/v0003/regional_seismicity_selection_circles.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10, 10))

lon, lat = eq['coordinates']

twice_RL = 90.

dist_in_deg = twice_RL/111.111

m = Basemap(projection='merc'
            ,llcrnrlon=lon-dist_in_deg
            ,llcrnrlat=lat-dist_in_deg
            ,urcrnrlon=lon+dist_in_deg
            ,urcrnrlat=lat+dist_in_deg
            , ax=ax
            , resolution='i'
            , area_thresh=1)

m.drawcoastlines()
m.fillcontinents(color='0.95', zorder=0)

lines = np.arange(0, 180, 0.5)
m.drawparallels(lines, labels=[1, 0, 0, 0], fontsize=15)
m.drawmeridians(lines, labels=[0,0,1,0], fontsize=15)

data = df_regional[df_regional.mag >= 2]
x, y = m(data.lon.values, data.lat.values)
# ax.scatter(x=x, y=y, s=np.exp(data.mag), alpha=0.5, color='None', edgecolor='black')
ax.scatter(x=x, y=y, s=np.exp(data.mag), alpha=0.5, c=data.depth, cmap='nipy_spectral')

# PLOT FAULT LINES
for fault in fault_coordinates:
    x, y = m(fault[:,0], fault[:,1])
    ax.plot(x, y, color='red', linewidth=2)    

for r in [5, 29, 57]:
    plotting.equi(ax=ax, m=m, radius=r, centerlon=eq['coordinates'][0], centerlat=eq['coordinates'][1]
                 ,color='black')
    x, y = m(eq['coordinates'][0], eq['coordinates'][1]+(r+1)/111.111)
    ax.text(s='{r}km'.format(r=r), x=x, y=y, fontsize=20)

    
x, y = m(131.2, 32.05)
ax.text(s='$\geq$M2', fontsize=30, x=x, y=y)

# ax3 = fig.add_axes([0.925, 0.15, 0.7, 0.7])
# data2 = polygon_selection.get_node_data(node=eq['coordinates'], data=df_regional, radius=twice_RL, m=1)


# RL = 45
# for r in [5, 15, 20, 25, 45, 90]:

    
#     eqs = polygon_selection.get_node_data(node=eq['coordinates']
#                                           ,data=df_regional.loc[df_regional.index >= '01-01-2001']
#                                           , radius=r, m=1)
#     h, e = np.histogram(a=eqs.mag, bins=100, range=(0, 10))
#     chist = np.cumsum(h[::-1])[::-1]
    
#     a, b, bstd, n, mc = stats.calc_fmd_stats_with_mc(eqs.mag)
#     ax3.scatter(e[:-1], chist, marker='s', alpha=0.5, label=None)
    
#     x = np.arange(0, 10, 0.1)
#     y = 10**(a - b * x)
    
    
#     ax3.plot(x, y, label='R={r}km, b={b}'.format(r=r, b=round(b, 2))+'$\pm$'+'{bstd}'.format(bstd=round(bstd,2)))
    
# ax3.set_yscale('log')
# ax3.set_ylim(1e0, 10**a)
# ax3.set_xlim(0, 6)
# ax3.set_xlabel('Magnitude', fontsize=15)
# ax3.set_ylabel('N Events', fontsize=15)
# ax3.legend(fontsize=15)

# for label in (ax3.get_xticklabels() + ax3.get_yticklabels()):
#     label.set_fontsize(15)
# fig.savefig('/home/max/Dropbox/Saves/v0003/regional_seismicity_selection_circles.pdf', bbox_inches='tight')
